# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
img =cv2.imread('../../RDJ and TH.jpg')

# %%
cv2.imshow("IMAGE",img)
cv2.waitKey(0)
# Out:
# 27

# %%
cv2.destroyWindow("IMAGE")

# %%
img.shape
# Out:
# (528, 792, 3)

# %%
img
# Out:
# array([[[204, 194, 184],
#         [204, 194, 184],
#         [204, 194, 184],
#         ...,
#         [200, 151, 125],
#         [200, 151, 125],
#         [199, 150, 124]],
#
#        [[204, 194, 184],
#         [204, 194, 184],
#         [204, 194, 184],
#         ...,
#         [199, 150, 124],
#         [198, 149, 123],
#         [198, 149, 123]],
#
#        [[204, 193, 185],
#         [204, 193, 185],
#         [205, 194, 186],
#         ...,
#         [198, 149, 123],
#         [199, 149, 121],
#         [198, 148, 120]],
#
#        ...,
#
#        [[ 90,  79,  81],
#         [ 89,  78,  80],
#         [ 84,  73,  75],
#         ...,
#         [ 61,  53,  54],
#         [ 65,  57,  58],
#         [ 49,  41,  42]],
#
#        [[ 90,  79,  81],
#         [ 90,  79,  81],
#         [ 86,  75,  77],
#         ...,
#         [ 65,  54,  56],
#         [ 65,  57,  58],
#         [ 55,  47,  48]],
#
#        [[ 84,  73,  75],
#         [ 86,  75,  77],
#         [ 85,  74,  76],
#         ...,
#         [ 61,  50,  52],
#         [ 57,  49,  50],
#         [ 56,  48,  49]]], dtype=uint8)

# %%
plt.imshow(img)

# %%
while True:
    cv2.imshow("FRAME",img)
    if cv2.waitKey(2)==27:
        break
cv2.destroyWindow("FRAME")

# %%
data=cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
data.detectMultiScale(img)
# Out:
# array([[157,  76, 156, 156],
#        [463,  48, 183, 183]])

# %%
while True:
    faces=data.detectMultiScale(img)
    for x,y,w,h in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,255),4)
    cv2.imshow("FRAME",img)
    if cv2.waitKey(2)==27:
        break
cv2.destroyWindow("FRAME")

# %%
capture=cv2.VideoCapture(0)
while True:
    
    flag,img=capture.read()
    if flag==1 :
        
        faces=data.detectMultiScale(img)
        for x,y,w,h in faces:
            
            cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,255),4)
        cv2.imshow("FRAME",img)
        if cv2.waitKey(2)==27:
            break
capture.release()
cv2.destroyAllWindows()
